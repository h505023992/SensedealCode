# %%
compare = 'jpg'
image = []
with open(r"image.txt",'r',encoding='utf-8') as f:
    line = f.readline()
    line = line.replace('\n','')
    while line:
        if compare in line:
            image.append(line)
        line = f.readline()
print(len(image))
print(image)
# Out:
# 7000
# ...
